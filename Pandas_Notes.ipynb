# %%
# Méthode .head(): Afficher les 5 premières lignes du DF
df.head()

# Ou bien afficher n lignes
df.head(n)

#affichage des dernières valeurs
print(df['column'].tail())

#Attribut .column : Afficher la liste des colonnes du DF
df.columns

# Attribut .shape : Dimensions du DF
df.shape
num_rows = df.shape[0]
num_col = df.shape[1]

#Méthode .loc[] : Sélectionner ligne on obtient un objet series
df.loc[n] 

#Méthode .loc[1:76] Pour afficher toutes les lignes de 1 à 75, lignes quise suivent...
df.loc[]

#Méthode1 .loc[var] Pour afficher plusieurs lignes qui ne se suivent pas...
#En passant par une variable intermédiaire 
var_lines = [x1, x6, x76]
df.loc[var_lines]

#Méthode2 .loc[[]] Pour afficher plusieurs lignes qui ne se suivent pas...
#Sans passer par une variable intermédiaire 
df.loc[[x1, x6, x76]]

#ASTUCE! Pour sélectionner les n dernières lignes d'un DF
row = df.shape[0]
df.loc[row-n:row-1]


#Attribut .dtypes : (type de données : object, int, float, bool, datetime)
#type de chaque colonne
df.dtypes #On obtient le type de données pour chaque colonnes

#informations sur les données
print(df.info())

#description des données
print(df.describe(include='all'))

#statistique descriptive
df['column'].describe()
count 270.000000
mean 54.433333
std 9.109067
min 29.000000
25% 48.000000
50% 55.000000
75% 61.000000
max 77.000000
Name: age, dtype: float64

#comptage des valeurs
print(df['typedouleur'].value_counts())

#un type Series est un vecteur, il est possible d'utiliser des indices
#première valeur
print(df['age'][0])




#Sélectionner une colonne : 1er exemple avec [''] et second exemple avec un nom de variable normalisé
df['column name']
df.column_name

#Sélectionner plusieurs colonnes 
df[['name1', 'name2', 'name3']]

#Sélectionner plusieurs colonnes en passant par une variable intermediaire
var = ['name1', 'name2', 'name3']
df[var]

# Méthode .tolist() pour convertir en liste
df.columns.tolist()

#Opérations mathématiques entre colonnes ou simplement avec un coed, etc...
df['column3'] = df['column1'] * df['column2']
df['column3'] / 100

#Normaliser une colonne, cad obtenir des valeurs comprises entre 0 et 1
#Méthode Series.max() avec le max, on pourra diviser les valeurs
df['column'].max()


#Création d'une colonne
df['new_column'] = ......

#Méthode .sort_values() : Trier un DF
df.sort_values('column')
#Et si je veux remplacer l'ancien DF par le nouveau 
df.sort_values('column', inplace=True)
#Trier par order décroissant : Par défaut ascending=True
df.sort_values('column', inplace=True, ascending=False)

#Ou sort_index() : Trie par son index


#Méthode .groupby() Pour grouper des colonnes.





#Fonction pd.isnull() : Valeurs manquantes NaN
var = df['column']
pd.isnull(var)
#Compter les valeurs manquantes avec len()
len()


#PB avec les valeurs manquantes pour les calculs
column_is_null = pd.isnull(df['column'])
var = df['column'][column_is_null == False]
mean_column = sum(var) / len(var)

#Calcul Moyenne avec la fonction series.mean()
df['column'].mean()


#Méthode df.pivot_table(index='', values='', aggfunc=np.mean)
#Pour Grouper et faire un calcul, par défaut ça sera mean
df.pivot_table(index='column_group', values='column_val')
df.pivot_table(index='column_group', values='column_val', aggfunc=np.mean)
df.pivot_table(index='column_group', values='column_val', aggfunc=np.sum)
df.pivot_table(index='column_group', values=['column_val1', 'column_val2', ....], aggfunc=np.mean)

#Méthode df.dropna(axis=0 pour les lignes ou axis=1 pour les colonnes)Supprimer les valeurs manquantes d'un DF
#Supprimer les lignes qui ont au moins une val manquantes, idem sur les colonnes
df.dropna(axis=0)
df.dropna(axis=0, subset=['col1','col2'])

#Index de colonnes
df.loc[n,c]
df.loc[n,:3]
df.loc[n,'column']



#Méthode df.reset_index() Réindexer un DF
#Ne pas conserver l'ancien indexage : df.reset_index(drop=True)
df.reset_index()

#Méthode .apply() : Pour appliquer une fonction sur colonne
df.apply(function)

#Méthode .apply(function, axis=1) : Pour appliquer une fonction sur lignes
df.apply(function, axis=1)




#Les structures de données :
# Objets Series : Utilisent les Tableaux Numpy
# DF
# Panels



#Transformer une colonne avec Numpy
np.add(series1, series2)
np.sin()
np.max()

#Filtrer et comparer objets Series
df['column'] > 50
